# %%
! pip install pandas
! pip install numpy
! pip install matplotlib
! pip install hmmlearn
! pip install requests
# Out:
# Requirement already satisfied: pandas in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.3-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.10 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from hmmlearn) (1.26.4)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from hmmlearn) (1.6.1)
# Requirement already satisfied: scipy>=0.19 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from hmmlearn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.5.0)
# Downloading hmmlearn-0.3.3-cp312-cp312-win_amd64.whl (127 kB)
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.3
# Requirement already satisfied: requests in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\scott\anaconda3\envs\intropython\lib\site-packages (from requests) (2024.12.14)

# %%
import requests

url = "https://drive.google.com/uc?export=download&id=1K4GGMCcmLtvsaI4lbncKhBTWDDCOPskg"
response = requests.get(url, stream=True)

with open("heart_rates.csv", "wb") as f:
    for chunk in response.iter_content(chunk_size=1024):
        f.write(chunk)

print("Download complete!")
# Out:
# Download complete!

# %% [markdown]
# You are collaborating with a research group who are trying to see the affect of exercise on mental health. As part of this, they are using fitbits to monitor heart rate and want you to help them determine when the participants are exercising, walking, or resting. Implement a GaussianHMM from hmmlearn (or yur choice of another package) to help them in this process
#
# A. Using the data and no prior knowledge, fit a Gaussian HMM and report the means and covariances of each state. Using the means, infer which state is resting, which is walking, and which is exercising (5 points)

# %%
import pandas as pd
import numpy as np
from hmmlearn import hmm
from hmmlearn.hmm import GaussianHMM
data = pd.read_csv('heart_rates.csv')
data
# Out:
#       Heart Rate
# 0      54.440599
# 1      61.594511
# 2      61.395206
# 3      65.052576
# 4      57.095609
# ...          ...
# 1995   61.000074
# 1996   52.554268
# 1997   60.470621
# 1998   66.684602
# 1999   65.912829
#
# [2000 rows x 1 columns]

# %%
observations = data["Heart Rate"]

# %%
print(observations)
# Out:
# 0       54.440599
# 1       61.594511
# 2       61.395206
# 3       65.052576
# 4       57.095609
#           ...
# 1995    61.000074
# 1996    52.554268
# 1997    60.470621
# 1998    66.684602
# 1999    65.912829
# Name: Heart Rate, Length: 2000, dtype: float64

# %%
#create a GaussianHMM model object with 3 components
hmm = GaussianHMM(n_components=3, covariance_type="full", n_iter=100, random_state=54)

# %%
#now fit in on the data
hmm.fit(data)
# Out:
# GaussianHMM(covariance_type='full', n_components=3, n_iter=100, random_state=54)

# %%
#extract the means and covariances
means=hmm.means_
covariances = hmm.covars_

# %%
print(means)
# Out:
# [[ 90.08374839]
#  [ 60.01822407]
#  [140.05187797]]

# %%
print(covariances)
# Out:
# [[[202.9471275 ]]
#
#  [[ 26.02919779]]
#
#  [[563.45714919]]]

# %%
#now predict the states
predicted_states = hmm.predict(data)

# %%
#assign values to each state level
states = {0:"Rest", 1:"Walk", 2:"Exercise"}

# %%
#call them what they are
predicted_state_names = [states[state] for state in predicted_states]

# %%
#get the data classified
classified_data = np.hstack((data, predicted_states.reshape(-1,1)))

# %%
print(classified_data[75:79])
# Out:
# [[64.36794708  1.        ]
#  [63.24543366  1.        ]
#  [53.88563232  1.        ]
#  [63.10274108  1.        ]]
